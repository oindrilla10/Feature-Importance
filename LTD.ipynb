# %%
# Defining the function for selection of the choices
# With every iteration, the loop asks for names and goes for different choices
def choices(name):
  # When the user has not selected anything
  choice = 0
  # Asking the user to input their preferred mode of study
  while(choice==0):
    choice = (int(input("Enter 1 for Online Mode. \nEnter 2 for Offline Mode.\n")))
    # Using the if loop to show the choice list according to the user's preference
    if choice == 1:
      print(f'You entered 1 and your preferred mode of studying is Online')
      print("Welcome to the online english courses provided by Christ University")
      print("Look through the list to choose the course of your choice")
      bts_choices(name,online_courses)
      break
    elif choice == 2:
      print(f'You entered 2 and your preferred mode of studying is offline')
      print("Welcome to the offline english courses provided by Christ University")
      print("Look through the list to choose the course of your choice")
      bts_choices(name,offline_courses)
      break
    else:
      print("Wrong choice, please try again")
      choice=0
  return count

# %%
#  Defining the function that will contain the parameters of the names and all the courses
def bts_choices(name, courses):
  # Creating a course dictionary that holds all of the courses
  course_dict = dict()
  # Creating a list of all the course details
  course_deets=[]
  nums=0
  # Assigning numerical values to the courses
  for num,course in enumerate(courses):
    course_dict.setdefault(num+1,course)
    # Printing the value and the course name
    print(str(num+1)+" "+course["Course_Name"])
    # Checking to see the user input
    nums=num
  i = int(input("Which course: "))
  # Getting the chosen course of the user
  if (i<=nums):
    course_deets=list(course_dict.get(i))
  else:
    bts_choices(name,courses)
    # Asking which detail the user wants to know

  choice=1
  while(choice!=0):
    for num,course_deet in enumerate(course_deets):
      nums=num
      print(str(num+1)+" "+course_deet)
    print("0 Exit\n")
    choice = int(input("Please choose next {} : ".format(name)))
    # Asking the user to choose between the range
    if(choice>nums+1):
      print("Please choose between 1 and {}".format(nums))
    print("\n")
    # If the user chooses from the range, getting his preffered course details
    if(choice<=nums and choice!=0):
      print(course_deets[choice-1]+" : "+course_dict.get(i).get(course_deets[choice-1])+"\n\n")
      # Asking the user if he wants to register
  reg = input("Do you want to register(y/n): ")
  # If user registers, increase the count by 1
  if(reg == 'y' or reg == "yes"):
    global count
    count = count+1
    # If user says no, ask if he wants to browse the course again or else exit
  if(reg=='n' or reg=="no"):
    again = input("do you browse the courses again(y/n): ")
    if(again=='y' or reg=="yes"):
      return choices(name)
    if(again=='n' or again=="no"):
      return

# %%
# Displaying the details of the online course
online_course1 = {"Course_Name":"Business English and Communication" , 
          "Course_Duration":"Six Months" , 
          "Course_Overview":"This Specialization is designed to teach you to communicate effectively in English in professional contexts. You will expand your English vocabulary, improve your ability to write and speak in English in both social and professional interactions, and learn terminology and skills that you can apply to business negotiations, telephone conversations, written reports and emails, and professional presentations",
        "Fee_Structure":"40,000 INR" ,
        "Course_Commencement_Date":"21st September, 2021" ,
        "Course_Instructor_Details":"Dr. ABHAYA N B (BA, MA, PhD)" ,
        "Examination_Structure":"CIA 1, CIA 2, ECE"}
online_course2 = {"Course_Name":"Learning English (Advanced Grammar and Punctuation)" , 
        "Course_Duration":"One year" , 
        "Course_Overview":"You will also learn how to blend verb tenses effectively and how to punctuate sentences correctly. This specialization is useful for non-native English speakers who want to improve their fluency or native speakers who want to improve their accuracy in using English for academic or professional purposes." ,
        "Fee_Structure":"1,00,000 INR" ,
        "Course_Commencement_Date":"1st December, 2021" ,
    "Course_Instructor_Details":"Dr. Bhavani S (BA, MA, PGDTE, MPhil, PhD )" ,
      "Examination_Structure":"CIA 1 , CIA 2, CIA 3, ESE"}
online_course3 = {"Course_Name":"English for Career Development" , 
        "Course_Duration":"One year" , 
        "Course_Overview":"You gain Communication and Writing Skills along with Career Development" ,
        "Fee_Structure":"1,20,000 INR" ,
        "Course_Commencement_Date":"1st December, 2021" ,
    "Course_Instructor_Details":"Dr. Rolla Das (BA MA PhD" ,
      "Examination_Structure":"CIA 1 , CIA 2, CIA 3, ESE"}

online_courses = [online_course1,online_course2,online_course3]

# %%
# Displaying the details of the offline course
offline_course_1 = {"Course_Name":"Bachelor of Arts Liberal Arts",
     "Objectives":"Position for students the significance of learning and higher education as being shaped, informed and conserved by the Sustainability Development Goals of the United Nations Engage students in the foundational concepts in historical enquiry such as fact, fiction, truth, narrative, memory, conservationism and counterfactuals – in the creation of any global narrative",
     "Fees Structure":"40,000 INR",
     "Course_Commencement_Date":"1st December, 2021" ,
        "Course_Instructor_Details":"Dr ARYA AIYAPPAN (MA, MPhil, PhD )" ,
         "Examination_Structure":"CIA 1 , CIA 2, CIA 3, ESE"   ,
     "Campus" : "Bangalore Bannerghata Campus"           
    }

offline_course_2 = {"Course_Name":"Bachelor of Arts (BA) Communication and Media, English and Psychology",
     "Objectives":"Academic expertise, Critical Thinking, Effective Communication, Social Interaction, Effective Citizenship",
     "Fees Structure":"1,00,000 INR",
     "Course_Commencement_Date":"1st December, 2021" ,
        "Course_Instructor_Details":"Dr SUMANJARI S  (MA, MPhil, PhD )" ,
         "Examination_Structure":"CIA 1 , CIA 2, CIA 3, ESE" ,
     "Campus": "Bangalore Central Campus"
    }

offline_course_3 = {"Course_Name":"Bachelor of Arts Journalism, Psychology, English",
     "Objectives":"Journalism, Psychology, English studies",
     "Fees Structure":"1,00,000 INR",
     "Course_Commencement_Date":"1st December, 2021" ,
        "Course_Instructor_Details":"Dr EDWIN JEEVARAJ A  (MA, MPhil, PhD )" ,
         "Examination_Structure":"CIA 1 , CIA 2, CIA 3, ESE" , 
         "Campus": "Bangalore Central Campus"
    }
    
offline_course_4 = {"Course_Name":"Bachelor of Arts Psychology, Sociology, English",
     "Objectives":"Psychology, Sociology, English studies",
     "Fees Structure":"1,00,000 INR",
     "Course_Commencement_Date":"1st December, 2021" ,
        "Course_Instructor_Details":"Dr JOHN JOSEPH KENNEDY P (MA, PGDES, MLitt, PhD  )" ,
         "Examination_Structure":"CIA 1 , CIA 2, CIA 3, ESE" , 
         "Campus": "Bangalore Central Campus"
    }

offline_course_5 = {"Course_Name":"Bachelor of Arts Performing Arts, English, Psychology",
     "Objectives":"Performing Arts, English studies, Psychology",
     "Fees Structure":"1,00,000 INR",
     "Course_Commencement_Date":"1st December, 2021" ,
        "Course_Instructor_Details":"Dr SHARON J (MA, MPhil, PhD )" ,
         "Examination_Structure":"CIA 1 , CIA 2, CIA 3, ESE" , 
         "Campus": "Bangalore Central Campus"
    }

offline_course_6 = {"Course_Name":"BA Bachelor of Arts (BA) Theatre Studies, English and Psychology",
     "Objectives":"Theatre Studies, English Studies, Psychology",
     "Fees Structure":"1,00,000 INR",
     "Course_Commencement_Date":"1st December, 2021" ,
        "Course_Instructor_Details":"Dr SWETA MUKHERJEE (MA, MPhil, PhD )" ,
         "Examination_Structure":"CIA 1 , CIA 2, CIA 3, ESE" , 
         "Campus": "Bangalore Central Campus"
    }

offline_course_7 = {"Course_Name":"Bachelor of Arts Music-Western Classical, Psychology, English",
     "Objectives":"Arts Music-Western Classical, Psychology, English Studies",
     "Fees Structure":"1,20,000 INR",
     "Course_Commencement_Date":"1st December, 2021" ,
        "Course_Instructor_Details":"Dr MITHILESH KUMAR (MA, MPhil, PhD )" ,
         "Examination_Structure":"CIA 1 , CIA 2, CIA 3, ESE",
         "Campus": "Bangalore Central Campus" , 
    }

offline_course_8 = {"Course_Name":" Bachelor of Arts English (Honours) ( Bangalore Bannerghatta Road Campus )",
     "Objectives":"Study skills, listening skills, reading skills, writing skills, search skills in library and in online databases, editing skills, bibliographic skills, dissertation skills, and critiquing skills, An introductory exposure to methods and methodologies in literary, cultural and historical domains, The ability to understand the complex dynamics of literary genres, The capability to interpret texts with critical, aesthetic, and ethical sensitivity, A higher consciousness of varied contemporary and decisive socio-political and cultural issues, An exposure to professional contexts and challenges, A preparedness to join higher education programmes in any premier institution in the world",
     "Fees Structure":"1,20,000 INR",
     "Course_Commencement_Date":"1st December, 2021" ,
        "Course_Instructor_Details":"Dr SAJI VARGHESE (MA, PhD )" ,
         "Examination_Structure":"CIA 1 , CIA 2, CIA 3, ESE" , 
         "Campus" : "Bangalore Bannerghata Campus" 
    }
offline_courses=[offline_course_1,offline_course_2,offline_course_3,offline_course_4,offline_course_5,offline_course_6,offline_course_7,offline_course_8]

# %%
# Introduction to Christ University English Programme
# Printing the Welcome Message
# Choosing the preferred mode of study
print("Welcome to Christ University (Department of English and Cultural Studies)")
print("We are here to provide you with the best English programme suited according to your needs")
print("We shall guide you every step of the way")
num_students = int(input("How many students are there : "))
count=0
while(num_students):
  name = input("Please enter your Name: ")
  print("Hello {}, please answer the questions below so that we can help you better".format(name))
  choices(name)
  num_students=num_students-1
print("Total BTS boys in university = {}".format(count))
# Out:
# Welcome to Christ University (Department of English and Cultural Studies)
# We are here to provide you with the best English programme suited according to your needs
# We shall guide you every step of the way
